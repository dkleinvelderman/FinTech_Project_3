# %%
import pandas as pd
from pandas import DataFrame
import requests
import os
import os.path
import datetime as dt
import json
import numpy as np
from datetime import timedelta, datetime
from dateutil import parser
import math
# %matplotlib inline
from matplotlib import pyplot as plt

from pathlib import Path
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.arima_model import ARMA

from dotenv import load_dotenv
load_dotenv()

import warnings
warnings.filterwarnings('ignore')

# %%
from kucoin.client import Client

api_key = '5f4a5b8e4128080006df7c63'
api_secret = 'c610ac4c-2754-4d5c-b39b-a3b055558413'
api_passphrase = 'STAGE001'

# %%
client = Client(api_key, api_secret, api_passphrase, sandbox=True)

# %%
# Load environment variables 
binance_api_key = os.getenv("GkFIyM2AydVGyMCNpp4snFLruNyWjlu4tPFXtzdwO5Ut7J0Gc1IactPdb6ZlrJXG")
binance_secret_key= os.getenv("Qg5PWRdkzsHP2KiLOPk3xsPDSRNmpukdIuGYjDrDkEllX1wCTfnNzDG9in4RXExn")

# %%
type(binance_api_key)
# Out:
# NoneType

# %%
type(binance_secret_key)
# Out:
# NoneType

# %%
# Set up client 
from binance.client import Client
binance_client = Client(api_key="GkFIyM2AydVGyMCNpp4snFLruNyWjlu4tPFXtzdwO5Ut7J0Gc1IactPdb6ZlrJXG", api_secret="Qg5PWRdkzsHP2KiLOPk3xsPDSRNmpukdIuGYjDrDkEllX1wCTfnNzDG9in4RXExn")

# Constants
binsizes = {"1m": 1, "5m": 5, "1h": 60, "1d": 1440}
batch_size = 750

# Create collecting new data function
def minutes_of_new_data(symbol, kline_size, data, source):
    if len(data) > 0:  old = parser.parse(data["timestamp"].iloc[-1])
    elif source == "binance": old = datetime.strptime('29 Aug 2020', '%d %b %Y')#<-- Can change start date here
    if source == "binance": new = pd.to_datetime(binance_client.get_klines(symbol=symbol, interval=kline_size)[-1][0], unit='ms')
    return old, new

# Create function to retreive tickers and timestamps
def get_all_binance(symbol, kline_size, save = False):
    filename = '%s-%s-data.csv' % (symbol, kline_size)
    if os.path.isfile(filename): data_df = pd.read_csv(filename)
    else: data_df = pd.DataFrame()
    oldest_point, newest_point = minutes_of_new_data(symbol, kline_size, data_df, source = "binance")
    delta_min = (newest_point - oldest_point).total_seconds()/60
    available_data = math.ceil(delta_min/binsizes[kline_size])
    if oldest_point == datetime.strptime('1 Jan 2015', '%d %b %Y'): print('Downloading all available %s data for %s. Be patient..!' % (kline_size, symbol))
    else: print('Downloading %d minutes of new data available for %s, i.e. %d instances of %s data.' % (delta_min, symbol, available_data, kline_size))
    klines = binance_client.get_historical_klines(symbol, kline_size, oldest_point.strftime("%d %b %Y %H:%M:%S"), newest_point.strftime("%d %b %Y %H:%M:%S"))
    data = pd.DataFrame(klines, columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av', 'ignore' ])
    data['timestamp'] = pd.to_datetime(data['timestamp'], unit='ms')
    if len(data_df) > 0:
        temp_df = pd.DataFrame(data)
        data_df = data_df.append(temp_df)
    else: data_df = data
    data_df.set_index('timestamp', inplace=True)
    if save: data_df.to_csv(filename)
    print('All caught up..!')
    return data_df

# %%
symbols = ['ETHUSDT', 'LINKUSDT','LTCUSDT', 'EOSUSDT', 'BTCUSDT']

# %%
price_data = []
for symbol in symbols:
    prices=get_all_binance(symbol, kline_size='1m')
    prices=prices.loc[:,['close']]
    price_data.append(prices.assign(coin=symbol))

coins = pd.concat(price_data)
coins
# Out:
# Downloading 1249 minutes of new data available for ETHUSDT, i.e. 1249 instances of 1m data.
# All caught up..!
# Downloading 1249 minutes of new data available for LINKUSDT, i.e. 1249 instances of 1m data.
# All caught up..!
# Downloading 1249 minutes of new data available for LTCUSDT, i.e. 1249 instances of 1m data.
# All caught up..!
# Downloading 1249 minutes of new data available for EOSUSDT, i.e. 1249 instances of 1m data.
# All caught up..!
# Downloading 1249 minutes of new data available for BTCUSDT, i.e. 1249 instances of 1m data.
# All caught up..!
#                               close     coin
# timestamp
# 2020-08-29 00:00:00    395.50000000  ETHUSDT
# 2020-08-29 00:01:00    395.35000000  ETHUSDT
# 2020-08-29 00:02:00    395.61000000  ETHUSDT
# 2020-08-29 00:03:00    395.45000000  ETHUSDT
# 2020-08-29 00:04:00    395.01000000  ETHUSDT
# 2020-08-29 00:05:00    394.83000000  ETHUSDT
# 2020-08-29 00:06:00    394.68000000  ETHUSDT
# 2020-08-29 00:07:00    394.48000000  ETHUSDT
# 2020-08-29 00:08:00    394.60000000  ETHUSDT
# 2020-08-29 00:09:00    394.65000000  ETHUSDT
# 2020-08-29 00:10:00    394.38000000  ETHUSDT
# 2020-08-29 00:11:00    394.40000000  ETHUSDT
# 2020-08-29 00:12:00    394.45000000  ETHUSDT
# 2020-08-29 00:13:00    394.12000000  ETHUSDT
# 2020-08-29 00:14:00    393.91000000  ETHUSDT
# 2020-08-29 00:15:00    393.97000000  ETHUSDT
# 2020-08-29 00:16:00    394.06000000  ETHUSDT
# 2020-08-29 00:17:00    393.94000000  ETHUSDT
# 2020-08-29 00:18:00    394.05000000  ETHUSDT
# 2020-08-29 00:19:00    393.98000000  ETHUSDT
# 2020-08-29 00:20:00    394.34000000  ETHUSDT
# 2020-08-29 00:21:00    394.39000000  ETHUSDT
# 2020-08-29 00:22:00    394.11000000  ETHUSDT
# 2020-08-29 00:23:00    394.01000000  ETHUSDT
# 2020-08-29 00:24:00    393.61000000  ETHUSDT
# 2020-08-29 00:25:00    393.55000000  ETHUSDT
# 2020-08-29 00:26:00    393.46000000  ETHUSDT
# 2020-08-29 00:27:00    393.63000000  ETHUSDT
# 2020-08-29 00:28:00    393.32000000  ETHUSDT
# 2020-08-29 00:29:00    393.36000000  ETHUSDT
# ...                             ...      ...
# 2020-08-29 20:20:00  11522.07000000  BTCUSDT
# 2020-08-29 20:21:00  11523.35000000  BTCUSDT
# 2020-08-29 20:22:00  11524.22000000  BTCUSDT
# 2020-08-29 20:23:00  11520.56000000  BTCUSDT
# 2020-08-29 20:24:00  11523.98000000  BTCUSDT
# 2020-08-29 20:25:00  11523.88000000  BTCUSDT
# 2020-08-29 20:26:00  11524.99000000  BTCUSDT
# 2020-08-29 20:27:00  11527.46000000  BTCUSDT
# 2020-08-29 20:28:00  11533.01000000  BTCUSDT
# 2020-08-29 20:29:00  11532.31000000  BTCUSDT
# 2020-08-29 20:30:00  11534.30000000  BTCUSDT
# 2020-08-29 20:31:00  11515.93000000  BTCUSDT
# 2020-08-29 20:32:00  11516.53000000  BTCUSDT
# 2020-08-29 20:33:00  11512.74000000  BTCUSDT
# 2020-08-29 20:34:00  11511.00000000  BTCUSDT
# 2020-08-29 20:35:00  11502.54000000  BTCUSDT
# 2020-08-29 20:36:00  11503.08000000  BTCUSDT
# 2020-08-29 20:37:00  11503.99000000  BTCUSDT
# 2020-08-29 20:38:00  11506.34000000  BTCUSDT
# 2020-08-29 20:39:00  11508.14000000  BTCUSDT
# 2020-08-29 20:40:00  11510.66000000  BTCUSDT
# 2020-08-29 20:41:00  11513.00000000  BTCUSDT
# 2020-08-29 20:42:00  11511.37000000  BTCUSDT
# 2020-08-29 20:43:00  11513.59000000  BTCUSDT
# 2020-08-29 20:44:00  11513.04000000  BTCUSDT
# 2020-08-29 20:45:00  11516.42000000  BTCUSDT
# 2020-08-29 20:46:00  11515.15000000  BTCUSDT
# 2020-08-29 20:47:00  11519.02000000  BTCUSDT
# 2020-08-29 20:48:00  11518.43000000  BTCUSDT
# 2020-08-29 20:49:00  11515.77000000  BTCUSDT
#
# [6250 rows x 2 columns]

# %%
coins.index.name = None

# %%
coins.head()
# Out:
#                             close     coin
# 2020-08-29 00:00:00  395.50000000  ETHUSDT
# 2020-08-29 00:01:00  395.35000000  ETHUSDT
# 2020-08-29 00:02:00  395.61000000  ETHUSDT
# 2020-08-29 00:03:00  395.45000000  ETHUSDT
# 2020-08-29 00:04:00  395.01000000  ETHUSDT

# %%
coins = coins.pivot(columns='coin')

# %%
coins.head()
# Out:
#                               close                                         \
# coin                        BTCUSDT     EOSUSDT       ETHUSDT     LINKUSDT
# 2020-08-29 00:00:00  11534.32000000  3.11810000  395.50000000  15.13330000
# 2020-08-29 00:01:00  11529.92000000  3.11690000  395.35000000  15.13060000
# 2020-08-29 00:02:00  11535.53000000  3.12160000  395.61000000  15.17750000
# 2020-08-29 00:03:00  11531.24000000  3.12050000  395.45000000  15.16080000
# 2020-08-29 00:04:00  11524.88000000  3.11970000  395.01000000  15.15100000
#
#
# coin                     LTCUSDT
# 2020-08-29 00:00:00  57.41000000
# 2020-08-29 00:01:00  57.39000000
# 2020-08-29 00:02:00  57.53000000
# 2020-08-29 00:03:00  57.56000000
# 2020-08-29 00:04:00  57.50000000

# %%
coins.columns = ['BTCUSDT', 'EOSUSDT','ETHUSDT','LINKUSDT','LTCUSDT']

# %%
coins.dtypes
# Out:
# BTCUSDT     object
# EOSUSDT     object
# ETHUSDT     object
# LINKUSDT    object
# LTCUSDT     object
# dtype: object

# %%
coins=coins.apply(pd.to_numeric)

# %%
df = coins

# %%
df.head()
# Out:
#                       BTCUSDT  EOSUSDT  ETHUSDT  LINKUSDT  LTCUSDT
# 2020-08-29 00:00:00  11534.32   3.1181   395.50   15.1333    57.41
# 2020-08-29 00:01:00  11529.92   3.1169   395.35   15.1306    57.39
# 2020-08-29 00:02:00  11535.53   3.1216   395.61   15.1775    57.53
# 2020-08-29 00:03:00  11531.24   3.1205   395.45   15.1608    57.56
# 2020-08-29 00:04:00  11524.88   3.1197   395.01   15.1510    57.50

# %%
df.tail()
# Out:
#                       BTCUSDT  EOSUSDT  ETHUSDT  LINKUSDT  LTCUSDT
# 2020-08-29 20:45:00  11516.42   3.1736   404.81   16.7435    57.71
# 2020-08-29 20:46:00  11515.15   3.1746   404.91   16.6937    57.69
# 2020-08-29 20:47:00  11519.02   3.1770   405.18   16.7263    57.69
# 2020-08-29 20:48:00  11518.43   3.1779   405.14   16.7263    57.69
# 2020-08-29 20:49:00  11515.77   3.1755   404.95   16.7294    57.66

# %%
independent = 'ETHUSDT'
dependent = 'BTCUSDT'

# %%
def generate_signals(df,independent,dependent,multiplier):
    df = df.pct_change()
    df = df.dropna()
    # define forecasting sample
    #f_sample = 50
    #df_insample = pd.DataFrame()
    #S = []
    residuals2_mean = []
    residuals2_std = []
    #for n in range(f_sample): #f_sample is the out-of-sample data
    #df_insample = df.iloc[0 : len(df)] #################################
    #X = df.ETHUSDT.values.reshape(-1, 1)
    #y = df.LTCUSDT
    X = df[independent].values.reshape(-1, 1)
    y = df[dependent]
    model = LinearRegression()
    model.fit(X, y)
    predicted_y_values = model.predict(X)
    residuals = df.loc[:,'ETHUSDT'] - predicted_y_values
    model_AR = ARMA(residuals.values, order = (1,0))
    results = model_AR.fit()
    a = results.params[0]
    b = results.params[1]
    kappa = -np.log(b)
    m = a / (1 - np.exp(-kappa))
    residuals_shifted = residuals.shift()
    residuals2 = residuals - (a + b*residuals_shifted)
    #residuals2_mean.append(residuals2.mean())
    #residuals2_std.append(residuals2.std())
    sigma_epsilon = residuals2.std()
    #sigma = sigma_epsilon / np.sqrt( (1 - np.exp(-2*kappa))/(2*kappa))
    #S.append(- m*np.sqrt(2*kappa)/sigma)
    #print(len(residuals2))
    df_results = pd.DataFrame()
    df_results['signal'] = np.where(residuals2 > multiplier*sigma_epsilon, -1.0, 0.0)
    df_results['signal'] = np.where(residuals2 < -multiplier*sigma_epsilon, 1.0, 0.0)
    return df_results['signal'].iloc[-1]

# %%
generate_signals(df,independent,dependent,0.0001)
# Out:
# 1.0

# %%
position = generate_signals(df,independent,dependent,0.0001)
if position == 1:
    client.create_market_order('BTC-USDT', Client.SIDE_BUY, funds=200)
    client.create_market_order('ETH-USDT', Client.SIDE_SELL, funds=200)
    print('sell dependent, buy independent')
elif position == -1:
    client.create_market_order('BTC-USDT', Client.SIDE_SELL, funds=200)
    client.create_market_order('ETH-USDT', Client.SIDE_BUY, funds=200)
    print('buy dependent, sell independent')
    
    
else:
    print('hold')
# Out:
# sell dependent, buy independent

# %%
import time

while True:
    time.sleep(30)
    print("Starting STAGE1")

    symbols = ['ETHUSDT','BTCUSDT']

    price_data = []
    for symbol in symbols:
        prices=get_all_binance(symbol, kline_size='1m')
        prices=prices.loc[:,['close']]
        price_data.append(prices.assign(coin=symbol))

    coins = pd.concat(price_data)
    
    coins.index.name = None 

    coins = coins.pivot(columns='coin')

    coins=coins.apply(pd.to_numeric)
   
    coins.columns = ['BTCUSDT','ETHUSDT']
    
    independent = 'ETHUSDT'
    dependent = 'BTCUSDT'
    
    accounts = client.get_account('5f4a6dbe7a4ece00071e4efd')
    
    position = generate_signals(df,independent,dependent,1)
    
    if position == 1:
        client.create_market_order('BTC-USDT', Client.SIDE_BUY, funds=1000)
        client.create_market_order('ETH-USDT', Client.SIDE_SELL, funds=1000)
        print('sell dependent, buy independent')
    elif position == -1:
        client.create_market_order('BTC-USDT', Client.SIDE_SELL, funds=1000)
        client.create_market_order('ETH-USDT', Client.SIDE_BUY, funds=1000)
        print('buy dependent, sell independent')
    
    else:
        print('hold')
    
    print (f"Your account balance:{accounts['balance']}")
# Out:
# Starting STAGE1
# Downloading 1273 minutes of new data available for ETHUSDT, i.e. 1273 instances of 1m data.
# All caught up..!
# Downloading 1273 minutes of new data available for BTCUSDT, i.e. 1273 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1273 minutes of new data available for ETHUSDT, i.e. 1273 instances of 1m data.
# All caught up..!
# Downloading 1274 minutes of new data available for BTCUSDT, i.e. 1274 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1274 minutes of new data available for ETHUSDT, i.e. 1274 instances of 1m data.
# All caught up..!
# Downloading 1274 minutes of new data available for BTCUSDT, i.e. 1274 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1275 minutes of new data available for ETHUSDT, i.e. 1275 instances of 1m data.
# All caught up..!
# Downloading 1275 minutes of new data available for BTCUSDT, i.e. 1275 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1275 minutes of new data available for ETHUSDT, i.e. 1275 instances of 1m data.
# All caught up..!
# Downloading 1275 minutes of new data available for BTCUSDT, i.e. 1275 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1276 minutes of new data available for ETHUSDT, i.e. 1276 instances of 1m data.
# All caught up..!
# Downloading 1276 minutes of new data available for BTCUSDT, i.e. 1276 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1276 minutes of new data available for ETHUSDT, i.e. 1276 instances of 1m data.
# All caught up..!
# Downloading 1276 minutes of new data available for BTCUSDT, i.e. 1276 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1277 minutes of new data available for ETHUSDT, i.e. 1277 instances of 1m data.
# All caught up..!
# Downloading 1277 minutes of new data available for BTCUSDT, i.e. 1277 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1278 minutes of new data available for ETHUSDT, i.e. 1278 instances of 1m data.
# All caught up..!
# Downloading 1278 minutes of new data available for BTCUSDT, i.e. 1278 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1278 minutes of new data available for ETHUSDT, i.e. 1278 instances of 1m data.
# All caught up..!
# Downloading 1278 minutes of new data available for BTCUSDT, i.e. 1278 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1279 minutes of new data available for ETHUSDT, i.e. 1279 instances of 1m data.
# All caught up..!
# Downloading 1279 minutes of new data available for BTCUSDT, i.e. 1279 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1279 minutes of new data available for ETHUSDT, i.e. 1279 instances of 1m data.
# All caught up..!
# Downloading 1279 minutes of new data available for BTCUSDT, i.e. 1279 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1280 minutes of new data available for ETHUSDT, i.e. 1280 instances of 1m data.
# All caught up..!
# Downloading 1280 minutes of new data available for BTCUSDT, i.e. 1280 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1280 minutes of new data available for ETHUSDT, i.e. 1280 instances of 1m data.
# All caught up..!
# Downloading 1280 minutes of new data available for BTCUSDT, i.e. 1280 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1281 minutes of new data available for ETHUSDT, i.e. 1281 instances of 1m data.
# All caught up..!
# Downloading 1281 minutes of new data available for BTCUSDT, i.e. 1281 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1281 minutes of new data available for ETHUSDT, i.e. 1281 instances of 1m data.
# All caught up..!
# Downloading 1281 minutes of new data available for BTCUSDT, i.e. 1281 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1282 minutes of new data available for ETHUSDT, i.e. 1282 instances of 1m data.
# All caught up..!
# Downloading 1282 minutes of new data available for BTCUSDT, i.e. 1282 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1283 minutes of new data available for ETHUSDT, i.e. 1283 instances of 1m data.
# All caught up..!
# Downloading 1283 minutes of new data available for BTCUSDT, i.e. 1283 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1283 minutes of new data available for ETHUSDT, i.e. 1283 instances of 1m data.
# All caught up..!
# Downloading 1283 minutes of new data available for BTCUSDT, i.e. 1283 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1284 minutes of new data available for ETHUSDT, i.e. 1284 instances of 1m data.
# All caught up..!
# Downloading 1284 minutes of new data available for BTCUSDT, i.e. 1284 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1284 minutes of new data available for ETHUSDT, i.e. 1284 instances of 1m data.
# All caught up..!
# Downloading 1284 minutes of new data available for BTCUSDT, i.e. 1284 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1285 minutes of new data available for ETHUSDT, i.e. 1285 instances of 1m data.
# All caught up..!
# Downloading 1285 minutes of new data available for BTCUSDT, i.e. 1285 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1285 minutes of new data available for ETHUSDT, i.e. 1285 instances of 1m data.
# All caught up..!
# Downloading 1285 minutes of new data available for BTCUSDT, i.e. 1285 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1286 minutes of new data available for ETHUSDT, i.e. 1286 instances of 1m data.
# All caught up..!
# Downloading 1286 minutes of new data available for BTCUSDT, i.e. 1286 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1287 minutes of new data available for ETHUSDT, i.e. 1287 instances of 1m data.
# All caught up..!
# Downloading 1287 minutes of new data available for BTCUSDT, i.e. 1287 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1287 minutes of new data available for ETHUSDT, i.e. 1287 instances of 1m data.
# All caught up..!
# Downloading 1287 minutes of new data available for BTCUSDT, i.e. 1287 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1288 minutes of new data available for ETHUSDT, i.e. 1288 instances of 1m data.
# All caught up..!
# Downloading 1288 minutes of new data available for BTCUSDT, i.e. 1288 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1288 minutes of new data available for ETHUSDT, i.e. 1288 instances of 1m data.
# All caught up..!
# Downloading 1288 minutes of new data available for BTCUSDT, i.e. 1288 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1289 minutes of new data available for ETHUSDT, i.e. 1289 instances of 1m data.
# All caught up..!
# Downloading 1289 minutes of new data available for BTCUSDT, i.e. 1289 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1289 minutes of new data available for ETHUSDT, i.e. 1289 instances of 1m data.
# All caught up..!
# Downloading 1289 minutes of new data available for BTCUSDT, i.e. 1289 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1290 minutes of new data available for ETHUSDT, i.e. 1290 instances of 1m data.
# All caught up..!
# Downloading 1290 minutes of new data available for BTCUSDT, i.e. 1290 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1290 minutes of new data available for ETHUSDT, i.e. 1290 instances of 1m data.
# All caught up..!
# Downloading 1290 minutes of new data available for BTCUSDT, i.e. 1290 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1291 minutes of new data available for ETHUSDT, i.e. 1291 instances of 1m data.
# All caught up..!
# Downloading 1291 minutes of new data available for BTCUSDT, i.e. 1291 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1292 minutes of new data available for ETHUSDT, i.e. 1292 instances of 1m data.
# All caught up..!
# Downloading 1292 minutes of new data available for BTCUSDT, i.e. 1292 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1292 minutes of new data available for ETHUSDT, i.e. 1292 instances of 1m data.
# All caught up..!
# Downloading 1292 minutes of new data available for BTCUSDT, i.e. 1292 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1293 minutes of new data available for ETHUSDT, i.e. 1293 instances of 1m data.
# All caught up..!
# Downloading 1293 minutes of new data available for BTCUSDT, i.e. 1293 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1293 minutes of new data available for ETHUSDT, i.e. 1293 instances of 1m data.
# All caught up..!
# Downloading 1293 minutes of new data available for BTCUSDT, i.e. 1293 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1294 minutes of new data available for ETHUSDT, i.e. 1294 instances of 1m data.
# All caught up..!
# Downloading 1294 minutes of new data available for BTCUSDT, i.e. 1294 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1294 minutes of new data available for ETHUSDT, i.e. 1294 instances of 1m data.
# All caught up..!
# Downloading 1294 minutes of new data available for BTCUSDT, i.e. 1294 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1295 minutes of new data available for ETHUSDT, i.e. 1295 instances of 1m data.
# All caught up..!
# Downloading 1295 minutes of new data available for BTCUSDT, i.e. 1295 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1295 minutes of new data available for ETHUSDT, i.e. 1295 instances of 1m data.
# All caught up..!
# Downloading 1296 minutes of new data available for BTCUSDT, i.e. 1296 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1296 minutes of new data available for ETHUSDT, i.e. 1296 instances of 1m data.
# All caught up..!
# Downloading 1296 minutes of new data available for BTCUSDT, i.e. 1296 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1297 minutes of new data available for ETHUSDT, i.e. 1297 instances of 1m data.
# All caught up..!
# Downloading 1297 minutes of new data available for BTCUSDT, i.e. 1297 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1297 minutes of new data available for ETHUSDT, i.e. 1297 instances of 1m data.
# All caught up..!
# Downloading 1297 minutes of new data available for BTCUSDT, i.e. 1297 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1298 minutes of new data available for ETHUSDT, i.e. 1298 instances of 1m data.
# All caught up..!
# Downloading 1298 minutes of new data available for BTCUSDT, i.e. 1298 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1298 minutes of new data available for ETHUSDT, i.e. 1298 instances of 1m data.
# All caught up..!
# Downloading 1298 minutes of new data available for BTCUSDT, i.e. 1298 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1299 minutes of new data available for ETHUSDT, i.e. 1299 instances of 1m data.
# All caught up..!
# Downloading 1299 minutes of new data available for BTCUSDT, i.e. 1299 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1299 minutes of new data available for ETHUSDT, i.e. 1299 instances of 1m data.
# All caught up..!
# Downloading 1299 minutes of new data available for BTCUSDT, i.e. 1299 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1300 minutes of new data available for ETHUSDT, i.e. 1300 instances of 1m data.
# All caught up..!
# Downloading 1300 minutes of new data available for BTCUSDT, i.e. 1300 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1301 minutes of new data available for ETHUSDT, i.e. 1301 instances of 1m data.
# All caught up..!
# Downloading 1301 minutes of new data available for BTCUSDT, i.e. 1301 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1301 minutes of new data available for ETHUSDT, i.e. 1301 instances of 1m data.
# All caught up..!
# Downloading 1301 minutes of new data available for BTCUSDT, i.e. 1301 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1302 minutes of new data available for ETHUSDT, i.e. 1302 instances of 1m data.
# All caught up..!
# Downloading 1302 minutes of new data available for BTCUSDT, i.e. 1302 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1302 minutes of new data available for ETHUSDT, i.e. 1302 instances of 1m data.
# All caught up..!
# Downloading 1302 minutes of new data available for BTCUSDT, i.e. 1302 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1303 minutes of new data available for ETHUSDT, i.e. 1303 instances of 1m data.
# All caught up..!
# Downloading 1303 minutes of new data available for BTCUSDT, i.e. 1303 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1303 minutes of new data available for ETHUSDT, i.e. 1303 instances of 1m data.
# All caught up..!
# Downloading 1303 minutes of new data available for BTCUSDT, i.e. 1303 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1304 minutes of new data available for ETHUSDT, i.e. 1304 instances of 1m data.
# All caught up..!
# Downloading 1304 minutes of new data available for BTCUSDT, i.e. 1304 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1304 minutes of new data available for ETHUSDT, i.e. 1304 instances of 1m data.
# All caught up..!
# Downloading 1305 minutes of new data available for BTCUSDT, i.e. 1305 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1305 minutes of new data available for ETHUSDT, i.e. 1305 instances of 1m data.
# All caught up..!
# Downloading 1305 minutes of new data available for BTCUSDT, i.e. 1305 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1306 minutes of new data available for ETHUSDT, i.e. 1306 instances of 1m data.
# All caught up..!
# Downloading 1306 minutes of new data available for BTCUSDT, i.e. 1306 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1306 minutes of new data available for ETHUSDT, i.e. 1306 instances of 1m data.
# All caught up..!
# Downloading 1306 minutes of new data available for BTCUSDT, i.e. 1306 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1307 minutes of new data available for ETHUSDT, i.e. 1307 instances of 1m data.
# All caught up..!
# Downloading 1307 minutes of new data available for BTCUSDT, i.e. 1307 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1307 minutes of new data available for ETHUSDT, i.e. 1307 instances of 1m data.
# All caught up..!
# Downloading 1307 minutes of new data available for BTCUSDT, i.e. 1307 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1308 minutes of new data available for ETHUSDT, i.e. 1308 instances of 1m data.
# All caught up..!
# Downloading 1308 minutes of new data available for BTCUSDT, i.e. 1308 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1308 minutes of new data available for ETHUSDT, i.e. 1308 instances of 1m data.
# All caught up..!
# Downloading 1308 minutes of new data available for BTCUSDT, i.e. 1308 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1309 minutes of new data available for ETHUSDT, i.e. 1309 instances of 1m data.
# All caught up..!
# Downloading 1309 minutes of new data available for BTCUSDT, i.e. 1309 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1309 minutes of new data available for ETHUSDT, i.e. 1309 instances of 1m data.
# All caught up..!
# Downloading 1310 minutes of new data available for BTCUSDT, i.e. 1310 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1310 minutes of new data available for ETHUSDT, i.e. 1310 instances of 1m data.
# All caught up..!
# Downloading 1310 minutes of new data available for BTCUSDT, i.e. 1310 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1311 minutes of new data available for ETHUSDT, i.e. 1311 instances of 1m data.
# All caught up..!
# Downloading 1311 minutes of new data available for BTCUSDT, i.e. 1311 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1311 minutes of new data available for ETHUSDT, i.e. 1311 instances of 1m data.
# All caught up..!
# Downloading 1311 minutes of new data available for BTCUSDT, i.e. 1311 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1312 minutes of new data available for ETHUSDT, i.e. 1312 instances of 1m data.
# All caught up..!
# Downloading 1312 minutes of new data available for BTCUSDT, i.e. 1312 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1312 minutes of new data available for ETHUSDT, i.e. 1312 instances of 1m data.
# All caught up..!
# Downloading 1312 minutes of new data available for BTCUSDT, i.e. 1312 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1313 minutes of new data available for ETHUSDT, i.e. 1313 instances of 1m data.
# All caught up..!
# Downloading 1313 minutes of new data available for BTCUSDT, i.e. 1313 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1313 minutes of new data available for ETHUSDT, i.e. 1313 instances of 1m data.
# All caught up..!
# Downloading 1314 minutes of new data available for BTCUSDT, i.e. 1314 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1314 minutes of new data available for ETHUSDT, i.e. 1314 instances of 1m data.
# All caught up..!
# Downloading 1314 minutes of new data available for BTCUSDT, i.e. 1314 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1315 minutes of new data available for ETHUSDT, i.e. 1315 instances of 1m data.
# All caught up..!
# Downloading 1315 minutes of new data available for BTCUSDT, i.e. 1315 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1315 minutes of new data available for ETHUSDT, i.e. 1315 instances of 1m data.
# All caught up..!
# Downloading 1315 minutes of new data available for BTCUSDT, i.e. 1315 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1316 minutes of new data available for ETHUSDT, i.e. 1316 instances of 1m data.
# All caught up..!
# Downloading 1316 minutes of new data available for BTCUSDT, i.e. 1316 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1316 minutes of new data available for ETHUSDT, i.e. 1316 instances of 1m data.
# All caught up..!
# Downloading 1316 minutes of new data available for BTCUSDT, i.e. 1316 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1317 minutes of new data available for ETHUSDT, i.e. 1317 instances of 1m data.
# All caught up..!
# Downloading 1317 minutes of new data available for BTCUSDT, i.e. 1317 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1317 minutes of new data available for ETHUSDT, i.e. 1317 instances of 1m data.
# All caught up..!
# Downloading 1317 minutes of new data available for BTCUSDT, i.e. 1317 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1318 minutes of new data available for ETHUSDT, i.e. 1318 instances of 1m data.
# All caught up..!
# Downloading 1318 minutes of new data available for BTCUSDT, i.e. 1318 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1319 minutes of new data available for ETHUSDT, i.e. 1319 instances of 1m data.
# All caught up..!
# Downloading 1319 minutes of new data available for BTCUSDT, i.e. 1319 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1319 minutes of new data available for ETHUSDT, i.e. 1319 instances of 1m data.
# All caught up..!
# Downloading 1319 minutes of new data available for BTCUSDT, i.e. 1319 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1320 minutes of new data available for ETHUSDT, i.e. 1320 instances of 1m data.
# All caught up..!
# Downloading 1320 minutes of new data available for BTCUSDT, i.e. 1320 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1320 minutes of new data available for ETHUSDT, i.e. 1320 instances of 1m data.
# All caught up..!
# Downloading 1320 minutes of new data available for BTCUSDT, i.e. 1320 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1321 minutes of new data available for ETHUSDT, i.e. 1321 instances of 1m data.
# All caught up..!
# Downloading 1321 minutes of new data available for BTCUSDT, i.e. 1321 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1321 minutes of new data available for ETHUSDT, i.e. 1321 instances of 1m data.
# All caught up..!
# Downloading 1321 minutes of new data available for BTCUSDT, i.e. 1321 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1322 minutes of new data available for ETHUSDT, i.e. 1322 instances of 1m data.
# All caught up..!
# Downloading 1322 minutes of new data available for BTCUSDT, i.e. 1322 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1323 minutes of new data available for ETHUSDT, i.e. 1323 instances of 1m data.
# All caught up..!
# Downloading 1323 minutes of new data available for BTCUSDT, i.e. 1323 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1323 minutes of new data available for ETHUSDT, i.e. 1323 instances of 1m data.
# All caught up..!
# Downloading 1323 minutes of new data available for BTCUSDT, i.e. 1323 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1324 minutes of new data available for ETHUSDT, i.e. 1324 instances of 1m data.
# All caught up..!
# Downloading 1324 minutes of new data available for BTCUSDT, i.e. 1324 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1324 minutes of new data available for ETHUSDT, i.e. 1324 instances of 1m data.
# All caught up..!
# Downloading 1324 minutes of new data available for BTCUSDT, i.e. 1324 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1325 minutes of new data available for ETHUSDT, i.e. 1325 instances of 1m data.
# All caught up..!
# Downloading 1325 minutes of new data available for BTCUSDT, i.e. 1325 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1325 minutes of new data available for ETHUSDT, i.e. 1325 instances of 1m data.
# All caught up..!
# Downloading 1325 minutes of new data available for BTCUSDT, i.e. 1325 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1326 minutes of new data available for ETHUSDT, i.e. 1326 instances of 1m data.
# All caught up..!
# Downloading 1326 minutes of new data available for BTCUSDT, i.e. 1326 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1326 minutes of new data available for ETHUSDT, i.e. 1326 instances of 1m data.
# All caught up..!
# Downloading 1326 minutes of new data available for BTCUSDT, i.e. 1326 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1327 minutes of new data available for ETHUSDT, i.e. 1327 instances of 1m data.
# All caught up..!
# Downloading 1327 minutes of new data available for BTCUSDT, i.e. 1327 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1328 minutes of new data available for ETHUSDT, i.e. 1328 instances of 1m data.
# All caught up..!
# Downloading 1328 minutes of new data available for BTCUSDT, i.e. 1328 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1328 minutes of new data available for ETHUSDT, i.e. 1328 instances of 1m data.
# All caught up..!
# Downloading 1328 minutes of new data available for BTCUSDT, i.e. 1328 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1329 minutes of new data available for ETHUSDT, i.e. 1329 instances of 1m data.
# All caught up..!
# Downloading 1329 minutes of new data available for BTCUSDT, i.e. 1329 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1329 minutes of new data available for ETHUSDT, i.e. 1329 instances of 1m data.
# All caught up..!
# Downloading 1329 minutes of new data available for BTCUSDT, i.e. 1329 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1330 minutes of new data available for ETHUSDT, i.e. 1330 instances of 1m data.
# All caught up..!
# Downloading 1330 minutes of new data available for BTCUSDT, i.e. 1330 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1330 minutes of new data available for ETHUSDT, i.e. 1330 instances of 1m data.
# All caught up..!
# Downloading 1330 minutes of new data available for BTCUSDT, i.e. 1330 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1331 minutes of new data available for ETHUSDT, i.e. 1331 instances of 1m data.
# All caught up..!
# Downloading 1331 minutes of new data available for BTCUSDT, i.e. 1331 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1332 minutes of new data available for ETHUSDT, i.e. 1332 instances of 1m data.
# All caught up..!
# Downloading 1332 minutes of new data available for BTCUSDT, i.e. 1332 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1332 minutes of new data available for ETHUSDT, i.e. 1332 instances of 1m data.
# All caught up..!
# Downloading 1332 minutes of new data available for BTCUSDT, i.e. 1332 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1333 minutes of new data available for ETHUSDT, i.e. 1333 instances of 1m data.
# All caught up..!
# Downloading 1333 minutes of new data available for BTCUSDT, i.e. 1333 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1333 minutes of new data available for ETHUSDT, i.e. 1333 instances of 1m data.
# All caught up..!
# Downloading 1333 minutes of new data available for BTCUSDT, i.e. 1333 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1334 minutes of new data available for ETHUSDT, i.e. 1334 instances of 1m data.
# All caught up..!
# Downloading 1334 minutes of new data available for BTCUSDT, i.e. 1334 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1334 minutes of new data available for ETHUSDT, i.e. 1334 instances of 1m data.
# All caught up..!
# Downloading 1334 minutes of new data available for BTCUSDT, i.e. 1334 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1335 minutes of new data available for ETHUSDT, i.e. 1335 instances of 1m data.
# All caught up..!
# Downloading 1335 minutes of new data available for BTCUSDT, i.e. 1335 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1335 minutes of new data available for ETHUSDT, i.e. 1335 instances of 1m data.
# All caught up..!
# Downloading 1335 minutes of new data available for BTCUSDT, i.e. 1335 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1336 minutes of new data available for ETHUSDT, i.e. 1336 instances of 1m data.
# All caught up..!
# Downloading 1336 minutes of new data available for BTCUSDT, i.e. 1336 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1337 minutes of new data available for ETHUSDT, i.e. 1337 instances of 1m data.
# All caught up..!
# Downloading 1337 minutes of new data available for BTCUSDT, i.e. 1337 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1337 minutes of new data available for ETHUSDT, i.e. 1337 instances of 1m data.
# All caught up..!
# Downloading 1337 minutes of new data available for BTCUSDT, i.e. 1337 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1338 minutes of new data available for ETHUSDT, i.e. 1338 instances of 1m data.
# All caught up..!
# Downloading 1338 minutes of new data available for BTCUSDT, i.e. 1338 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1338 minutes of new data available for ETHUSDT, i.e. 1338 instances of 1m data.
# All caught up..!
# Downloading 1338 minutes of new data available for BTCUSDT, i.e. 1338 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1339 minutes of new data available for ETHUSDT, i.e. 1339 instances of 1m data.
# All caught up..!
# Downloading 1339 minutes of new data available for BTCUSDT, i.e. 1339 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1339 minutes of new data available for ETHUSDT, i.e. 1339 instances of 1m data.
# All caught up..!
# Downloading 1339 minutes of new data available for BTCUSDT, i.e. 1339 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1340 minutes of new data available for ETHUSDT, i.e. 1340 instances of 1m data.
# All caught up..!
# Downloading 1340 minutes of new data available for BTCUSDT, i.e. 1340 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1340 minutes of new data available for ETHUSDT, i.e. 1340 instances of 1m data.
# All caught up..!
# Downloading 1341 minutes of new data available for BTCUSDT, i.e. 1341 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1341 minutes of new data available for ETHUSDT, i.e. 1341 instances of 1m data.
# All caught up..!
# Downloading 1341 minutes of new data available for BTCUSDT, i.e. 1341 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1342 minutes of new data available for ETHUSDT, i.e. 1342 instances of 1m data.
# All caught up..!
# Downloading 1342 minutes of new data available for BTCUSDT, i.e. 1342 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1342 minutes of new data available for ETHUSDT, i.e. 1342 instances of 1m data.
# All caught up..!
# Downloading 1342 minutes of new data available for BTCUSDT, i.e. 1342 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1343 minutes of new data available for ETHUSDT, i.e. 1343 instances of 1m data.
# All caught up..!
# Downloading 1343 minutes of new data available for BTCUSDT, i.e. 1343 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1343 minutes of new data available for ETHUSDT, i.e. 1343 instances of 1m data.
# All caught up..!
# Downloading 1343 minutes of new data available for BTCUSDT, i.e. 1343 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1344 minutes of new data available for ETHUSDT, i.e. 1344 instances of 1m data.
# All caught up..!
# Downloading 1344 minutes of new data available for BTCUSDT, i.e. 1344 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1344 minutes of new data available for ETHUSDT, i.e. 1344 instances of 1m data.
# All caught up..!
# Downloading 1344 minutes of new data available for BTCUSDT, i.e. 1344 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1345 minutes of new data available for ETHUSDT, i.e. 1345 instances of 1m data.
# All caught up..!
# Downloading 1345 minutes of new data available for BTCUSDT, i.e. 1345 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1346 minutes of new data available for ETHUSDT, i.e. 1346 instances of 1m data.
# All caught up..!
# Downloading 1346 minutes of new data available for BTCUSDT, i.e. 1346 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1346 minutes of new data available for ETHUSDT, i.e. 1346 instances of 1m data.
# All caught up..!
# Downloading 1346 minutes of new data available for BTCUSDT, i.e. 1346 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1347 minutes of new data available for ETHUSDT, i.e. 1347 instances of 1m data.
# All caught up..!
# Downloading 1347 minutes of new data available for BTCUSDT, i.e. 1347 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1347 minutes of new data available for ETHUSDT, i.e. 1347 instances of 1m data.
# All caught up..!
# Downloading 1347 minutes of new data available for BTCUSDT, i.e. 1347 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1348 minutes of new data available for ETHUSDT, i.e. 1348 instances of 1m data.
# All caught up..!
# Downloading 1348 minutes of new data available for BTCUSDT, i.e. 1348 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1348 minutes of new data available for ETHUSDT, i.e. 1348 instances of 1m data.
# All caught up..!
# Downloading 1348 minutes of new data available for BTCUSDT, i.e. 1348 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1349 minutes of new data available for ETHUSDT, i.e. 1349 instances of 1m data.
# All caught up..!
# Downloading 1349 minutes of new data available for BTCUSDT, i.e. 1349 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1349 minutes of new data available for ETHUSDT, i.e. 1349 instances of 1m data.
# All caught up..!
# Downloading 1349 minutes of new data available for BTCUSDT, i.e. 1349 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# Starting STAGE1
# Downloading 1350 minutes of new data available for ETHUSDT, i.e. 1350 instances of 1m data.
# All caught up..!
# Downloading 1350 minutes of new data available for BTCUSDT, i.e. 1350 instances of 1m data.
# All caught up..!
# hold
# Your account balance:38698.20833711
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-29af9d764dcb> in <module>
#       2
#       3 while True:
# ----> 4     time.sleep(30)
#       5     print("Starting STAGE1")
#       6
#
# KeyboardInterrupt:

# %%
accounts = client.get_accounts()

# %%
accounts
# Out:
# [{'id': '5f4a6db41d6b2a0006066c80',
#   'currency': 'BTC',
#   'type': 'trade',
#   'balance': '5.94258804',
#   'available': '5.94258804',
#   'holds': '0'},
#  {'id': '5f4a6dbe7a4ece00071e4efd',
#   'currency': 'USDT',
#   'type': 'trade',
#   'balance': '38703.8076925',
#   'available': '38703.8076925',
#   'holds': '0'},
#  {'id': '5f4a6dc61d6b2a0006066eec',
#   'currency': 'ETH',
#   'type': 'trade',
#   'balance': '51.00118469',
#   'available': '51.00118469',
#   'holds': '0'},
#  {'id': '5f4a58ae1d6b2a0006039824',
#   'currency': 'BTC',
#   'type': 'main',
#   'balance': '0',
#   'available': '0',
#   'holds': '0'},
#  {'id': '5f4a58ae1d6b2a000603982e',
#   'currency': 'ETH',
#   'type': 'main',
#   'balance': '0',
#   'available': '0',
#   'holds': '0'},
#  {'id': '5f4a58ae1d6b2a000603982b',
#   'currency': 'USDT',
#   'type': 'main',
#   'balance': '0',
#   'available': '0',
#   'holds': '0'}]

# %%
currencies = client.get_currencies()

# %%
klines = client.get_kline_data('ETH-USDT')

# %%
currencies = client.get_currencies()

# %%
currency = client.get_currency('BTC')

# %%
accounts = client.get_accounts()

# %%
accounts

# %%
account = client.create_account('trade', 'BTC')

# %%
order = client.create_market_order('BTC-USDT', Client.SIDE_BUY, size=0.5)

# %%
order
# Out:
# {'orderId': '5f4a7ab5381ff50007c6a350'}
